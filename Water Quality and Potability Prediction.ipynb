# %% [markdown]
# ## Importing Dependencies

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/Appa/Documents/DataScience/water_potability.csv")

# %% [markdown]
# ## Data Check

# %%
df.shape
# Out:
# (3276, 10)

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df.isna().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isna().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Univariate Relationships

# %%
plt.figure(figsize=(15,10))
plt.title('Potability of Water with respect to pH')
sns.histplot(x = 'ph', hue = 'Potability', kde = True, data = df)
# Out:
# <AxesSubplot:title={'center':'Potability of Water with respect to pH'}, xlabel='ph', ylabel='Count'>

# %%
plt.figure(figsize=(15,10))
plt.title('Potability of Water with respect to Hardness')
sns.histplot(x = 'Hardness', hue = 'Potability', kde = True, data = df)
# Out:
# <AxesSubplot:title={'center':'Potability of Water with respect to Hardness'}, xlabel='Hardness', ylabel='Count'>

# %%
plt.figure(figsize=(15,10))
plt.title('Potability of Water with respect to Conductivity')
sns.histplot(x = 'Conductivity', hue = 'Potability', kde = True, data = df)
# Out:
# <AxesSubplot:title={'center':'Potability of Water with respect to Conductivity'}, xlabel='Conductivity', ylabel='Count'>

# %%
plt.figure(figsize=(15,10))
plt.title('Potability of Water with respect to pH')
sns.histplot(x = 'Chloramines', hue = 'Potability', kde = True, data = df)
# Out:
# <AxesSubplot:title={'center':'Potability of Water with respect to pH'}, xlabel='Chloramines', ylabel='Count'>

# %%
plt.figure(figsize=(15,10))
plt.title('Potability of Water with respect to Solids')
sns.histplot(x = 'Solids', hue = 'Potability', kde = True, data = df)
# Out:
# <AxesSubplot:title={'center':'Potability of Water with respect to Solids'}, xlabel='Solids', ylabel='Count'>

# %%
plt.figure(figsize=(15,10))
plt.title('Potability of Water with respect to Sulfates')
sns.histplot(x = 'Sulfate', hue = 'Potability', kde = True, data = df)
# Out:
# <AxesSubplot:title={'center':'Potability of Water with respect to Sulfates'}, xlabel='Sulfate', ylabel='Count'>

# %%
plt.figure(figsize=(15,10))
plt.title('Potability of Water with respect to Organic Carbons')
sns.histplot(x = 'Organic_carbon', hue = 'Potability', kde = True, data = df)
# Out:
# <AxesSubplot:title={'center':'Potability of Water with respect to Organic Carbons'}, xlabel='Organic_carbon', ylabel='Count'>

# %%
plt.figure(figsize=(15,10))
plt.title('Potability of Water with respect to Trihalomethanes')
sns.histplot(x = 'Trihalomethanes', hue = 'Potability', kde = True, data = df)
# Out:
# <AxesSubplot:title={'center':'Potability of Water with respect to Trihalomethanes'}, xlabel='Trihalomethanes', ylabel='Count'>

# %%
plt.figure(figsize=(15,10))
plt.title('Potability of Water with respect to Turbidity')
sns.histplot(x = 'Turbidity', hue = 'Potability', kde = True, data = df)
# Out:
# <AxesSubplot:title={'center':'Potability of Water with respect to Turbidity'}, xlabel='Turbidity', ylabel='Count'>

# %% [markdown]
# ### Multivariate Relationships

# %%
df_corr = df.corr()
plt.figure(figsize=(15,10))
plt.title('Relationships between parameters')
sns.heatmap(df_corr, annot = True, cmap = 'Blues')
# Out:
# <AxesSubplot:title={'center':'Relationships between parameters'}>

# %% [markdown]
# ### Results:
# 1. Very few notable relationships. Only noteworthy correlations are the high negative correlation of Solids, and Hardness of water with Sulfates, meaning that as the Sulfate concentration in water increases, hardness of water and solids decrease.
# 2. Largest influencers of Potability of Water from the features are Soilds concentration, Organic Carbon concentration, Chloramine concentration, and Sulfate concentration.
# 3. Turbidity of the water has the least correlation with Potability followed by pH, Trihalomethance concentration, and Conductivity of the water sample.

# %% [markdown]
# ## Predictive Analysis

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import svm
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor

# %%
X = df.drop(columns = 'Potability')
Y = df['Potability']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 2)

# %%
print(X_train.shape, X_test.shape, X.shape)
# Out:
# (1608, 9) (403, 9) (2011, 9)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
print('Mean Squared Error = ', mean_squared_error(model.predict(X_test), Y_test))
# Out:
# Mean Squared Error =  0.23852833827757977

# %%
model = svm.SVR()
model.fit(X_train, Y_train)
print('Mean Squared Error = ', mean_squared_error(model.predict(X_test), Y_test))
# Out:
# Mean Squared Error =  0.32402445903660715

# %%
model = RandomForestRegressor(n_estimators = 36)
model.fit(X_train, Y_train)
print('Mean Squared Error = ', mean_squared_error(model.predict(X_test), Y_test))
# Out:
# Mean Squared Error =  0.20885794810525993

# %%
model = GradientBoostingRegressor()
model.fit(X_train, Y_train)
print('Mean Squared Error = ', mean_squared_error(model.predict(X_test), Y_test))
# Out:
# Mean Squared Error =  0.21770560209766568

# %%
model = XGBRegressor()
model.fit(X_train, Y_train)
print('Mean Squared Error = ', mean_squared_error(model.predict(X_test), Y_test))
# Out:
# Mean Squared Error =  0.2519683265331464

# %%
model = LGBMRegressor()
model.fit(X_train, Y_train)
print('Mean Squared Error = ', mean_squared_error(model.predict(X_test), Y_test))
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000472 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 1608, number of used features: 9
# [LightGBM] [Info] Start training from score 0.405473
# Mean Squared Error =  0.23132015704974554

# %%
model = CatBoostRegressor()
model.fit(X_train, Y_train)
print('Mean Squared Error = ', mean_squared_error(model.predict(X_test), Y_test))
# Out:
# Learning rate set to 0.044134
# 0:	learn: 0.4895431	total: 159ms	remaining: 2m 38s
# 1:	learn: 0.4875080	total: 163ms	remaining: 1m 21s
# 2:	learn: 0.4852390	total: 166ms	remaining: 55.3s
# 3:	learn: 0.4841323	total: 169ms	remaining: 42.1s
# 4:	learn: 0.4821768	total: 173ms	remaining: 34.3s
# 5:	learn: 0.4808673	total: 177ms	remaining: 29.3s
# 6:	learn: 0.4792168	total: 180ms	remaining: 25.5s
# 7:	learn: 0.4776160	total: 183ms	remaining: 22.7s
# 8:	learn: 0.4766902	total: 186ms	remaining: 20.4s
# 9:	learn: 0.4753903	total: 188ms	remaining: 18.6s
# 10:	learn: 0.4744499	total: 192ms	remaining: 17.2s
# 11:	learn: 0.4727287	total: 195ms	remaining: 16.1s
# 12:	learn: 0.4716602	total: 198ms	remaining: 15.1s
# 13:	learn: 0.4695959	total: 201ms	remaining: 14.2s
# 14:	learn: 0.4680240	total: 204ms	remaining: 13.4s
# 15:	learn: 0.4670456	total: 206ms	remaining: 12.7s
# 16:	learn: 0.4652896	total: 209ms	remaining: 12.1s
# 17:	learn: 0.4642125	total: 212ms	remaining: 11.5s
# ...

# %% [markdown]
# ### Results:
# 1. Random Forest Regressor predicts the dataset most accurately with an total decision tree count of 36 and a mean squared error accuracy of 0.2089
# 2. Simple Linear Regression predicts the dataset with a mean squared error of 0.2385
# 3. Gradient Boosting Regressor from sklearn is the best boosting algorithm with a mean squared error of 0.2177
